# %% [markdown]
# ### Create large matrixs
#
# This notebook computes ISC per spot/condition, and collects corresponding memory data (recognition, recall). All is saved into a large structure that is then read into R.

# %%
#note: I manually deleted those few data files for which there are problems with the pupil recording (mostly sub012 and sub055) -- this could be automated.

# %%
import os, glob, warnings, re, shutil
import numpy as np
import pandas as pd
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import zscore
from scipy.stats import ttest_1samp
from scipy.stats import pearsonr
from scipy.spatial.distance import squareform

# %%
def pupil_isc(data, pairwise=True, summary_statistic=np.mean, verbose=True):
    """Intersubject correlation
    For each voxel or ROI, compute the Pearson correlation between each
    subject's response time series and other subjects' response time series.
    If pairwise is False (default), use the leave-one-out approach, where
    correlation is computed between each subject and the average of the other
    subjects. If pairwise is True, compute correlations between all pairs of
    subjects. If summary_statistic is None, return N ISC values for N subjects
    (leave-one-out) or N(N-1)/2 ISC values for each pair of N subjects,
    corresponding to the upper triangle of the pairwise correlation matrix
    (see scipy.spatial.distance.squareform). Alternatively, supply either
    np.mean or np.median to compute summary statistic of ISCs (Fisher Z will
    be applied and inverted if using mean). Input data should be a list 
    where each item is a time-points by voxels ndarray for a given subject.
    Multiple input ndarrays must be the same shape. If a single ndarray is
    supplied, the last dimension is assumed to correspond to subjects. If 
    only two subjects are supplied, simply compute Pearson correlation
    (precludes averaging in leave-one-out approach, and does not apply
    summary statistic.) Output is an ndarray where the first dimension is
    the number of subjects or pairs and the second dimension is the number
    of voxels (or ROIs).
        
    The implementation is based on the following publication:
    
    .. [Hasson2004] "Intersubject synchronization of cortical activity 
    during natural vision.", U. Hasson, Y. Nir, I. Levy, G. Fuhrmann,
    R. Malach, 2004, Science, 303, 1634-1640.
    Parameters
    ----------
    data : list or ndarray
        fMRI data for which to compute ISC
        
    pairwise : bool, default: False
        Whether to use pairwise (True) or leave-one-out (False) approach
        
    summary_statistic : None
        Return all ISCs or collapse using np.mean or np.median
    Returns
    -------
    iscs : subjects or pairs by voxels ndarray
        ISC for each subject or pair (or summary statistic) per voxel
    """
    
    # Convert list input to 3d and check shapes
    if type(data) == list:
        data_shape = data[0].shape
        for i, d in enumerate(data):
            if d.shape != data_shape:
                raise ValueError("All ndarrays in input list "
                                 "must be the same shape!")
            if d.ndim == 1:
                data[i] = d[:, np.newaxis]
        data = np.dstack(data)

    # Convert input ndarray to 3d and check shape
    elif type(data) == np.ndarray:
        if data.ndim == 2:
            data = data[:, np.newaxis, :]            
        elif data.ndim == 3:
            pass
        else:
            raise ValueError("Input ndarray should have 2 "
                             f"or 3 dimensions (got {data.ndim})!")

    # Infer subjects, TRs, voxels and print for user to check
    n_subjects = data.shape[2]
    n_TRs = data.shape[0]
    n_voxels = data.shape[1]
    if verbose:
        print(f"Assuming {n_subjects} subjects with {n_TRs} time points "
              f"and {n_voxels} voxel(s) or ROI(s).")
    
    # Loop over each voxel or ROI
    voxel_iscs = []
    for v in np.arange(n_voxels):
        voxel_data = data[:, v, :].T
        if n_subjects == 2:
            iscs = pearsonr(voxel_data[0, :], voxel_data[1, :])[0]
            summary_statistic = None
            if verbose:
                print("Only two subjects! Simply computing Pearson correlation.")
        elif pairwise:
            iscs = squareform(np.corrcoef(voxel_data), checks=False)
        elif not pairwise:
            iscs = np.array([pearsonr(subject,
                                      np.mean(np.delete(voxel_data,
                                                        s, axis=0),
                                              axis=0))[0]
                    for s, subject in enumerate(voxel_data)])
        voxel_iscs.append(iscs)
    iscs = np.column_stack(voxel_iscs)
    
    # Summarize results (if requested)
    if summary_statistic == np.nanmean:
        iscs = np.tanh(np.nanmean(np.arctanh(iscs), axis=0))[np.newaxis, :]
    elif summary_statistic == np.mean:
        iscs = np.tanh(np.mean(np.arctanh(iscs), axis=0))[np.newaxis, :]
    elif summary_statistic == np.median:    
        iscs = summary_statistic(iscs, axis=0)[np.newaxis, :]
    elif not summary_statistic:
        pass
    else:
        raise ValueError("Unrecognized summary_statistic! Use None, np.median, or np.mean.")
    return iscs

# %%
# prepare spots
spot_list = ['commercial_aribnb_30s', 'commercial_att_30s', 'commercial_carscom_30s','commercial_cookies_30s',
             'commercial_dominos_30s', 'commercial_doritos_30s','commercial_expedia_30s','commercial_google_pixel_30s',
             'commercial_hr_block_30s','commercial_jersey_mikes_30s','commercial_lego_30s','commercial_meta_quest_2_30s',
             'commercial_milk_30s','commercial_progressive_30s','commercial_publix_30s','commercial_puma_30s',
             'commercial_starbucks_30s','commercial_under_armour_30s',
             'health_alcohol_30s','health_alzheimers_30s','health_covid_vaccine_30s','health_diet_30s',
             'health_drunk_driving_30s','health_fitness_30s','health_kidney_30s','health_mantherapy_30s',
             'health_prediabetes_30s','health_stroke_30s','health_vaping_30s','health_weight_30s']

n_spots = len(spot_list)

spot_list.sort()
print(len(spot_list))
print(spot_list[:3])

# prepare subject list
sub_folders = glob.glob("../data/00_raw_data/sub*")
sub_folders.sort()
subject_list = []
for f in sub_folders:
    subject_list.append(f[-6:])

n_subjects = len(subject_list)
print(n_subjects)
print(subject_list[:3])

condition_list = ['100', '50nd', '50wd']
n_conditions = len(condition_list)
# Out:
# 30
# ['commercial_aribnb_30s', 'commercial_att_30s', 'commercial_carscom_30s']
# 59
# ['sub001', 'sub002', 'sub003']

# %%
stack_subs = subject_list * n_spots * n_conditions
stack_subs.sort()
print(len(stack_subs))

stack_conditions = condition_list * n_subjects * n_spots
print(len(stack_conditions))

stack_spots = spot_list  * n_conditions
stack_spots.sort()
stack_spots = stack_spots * n_subjects
print(len(stack_spots))


#create results df
df = pd.DataFrame(stack_subs, columns = ['subject'])
df['condition'] = stack_conditions
df['spot'] = stack_spots
df['recall'] = np.nan
df['recognition'] = np.nan
df['isc_ind2rest'] = np.nan
del stack_subs, stack_spots, stack_conditions
df

#df['condition'] = condition_list * n_subjects * n_spots
#df.loc[(df['condition'] == '100') & (df['subject'] == 'sub001')]
df
# Out:
# 5310
# 5310
# 5310
#      subject condition                   spot  recall  recognition  \
# 0     sub001       100  commercial_aribnb_30s     NaN          NaN
# 1     sub001      50nd  commercial_aribnb_30s     NaN          NaN
# 2     sub001      50wd  commercial_aribnb_30s     NaN          NaN
# 3     sub001       100     commercial_att_30s     NaN          NaN
# 4     sub001      50nd     commercial_att_30s     NaN          NaN
# ...      ...       ...                    ...     ...          ...
# 5305  sub060      50nd      health_vaping_30s     NaN          NaN
# 5306  sub060      50wd      health_vaping_30s     NaN          NaN
# 5307  sub060       100      health_weight_30s     NaN          NaN
# 5308  sub060      50nd      health_weight_30s     NaN          NaN
# 5309  sub060      50wd      health_weight_30s     NaN          NaN
#
#       isc_ind2rest
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 5305           NaN
# 5306           NaN
# 5307           NaN
# 5308           NaN
# 5309           NaN
#
# [5310 rows x 6 columns]

# %%
x_length = 725

search_file_path = '../data/03_spots_memory_data/'


for current_spot_index in range(n_spots):
    current_spot = spot_list[current_spot_index]
    print(current_spot)

    for current_condition_index in range(n_conditions): 
        current_condition = condition_list[current_condition_index]
        print(current_condition)
        
        memory_pupil_data = []


        curr_search_folder = search_file_path + current_spot + '/' + current_condition + '/' 
        #print(curr_search_folder)

        memory_spot = glob.glob(os.path.join(curr_search_folder, '*recall*.csv'))
        memory_spot.sort()
        n_memory_spot = len(memory_spot)
        #print(n_memory_spot)
        
        memory_spot2 = glob.glob(os.path.join(curr_search_folder, '*recognition*.csv'))
        memory_spot2.sort()
        n_memory_spot2 = len(memory_spot2)
        #print(n_memory_spot2)

        if n_memory_spot2 != n_memory_spot:
            print('attention')
            
        
        #print('---')

        for curr_sub in range(n_memory_spot):

                    curr_file = memory_spot[curr_sub]
                    #print(curr_file)

                    curr_data =     pd.read_csv(curr_file)['pupil diameter']
                    curr_data_int = curr_data.interpolate(limit_direction='both' ).values[:x_length]
                    curr_data_int = curr_data_int - np.nanmean(curr_data_int[:300]) #subtract baseline
                    memory_pupil_data.append((curr_data_int[300:])) 
        this_spot_data = np.asarray(memory_pupil_data)

        print(this_spot_data.shape)

        arr = list(np.arange( n_memory_spot))
        #print(arr)

        for i, curr_sub in enumerate(arr):
            the_rest = arr[:i] + arr[i+1:]
            #print(curr_sub, the_rest)
            curr_sub_data = this_spot_data[curr_sub,:]
            other_data = np.mean(this_spot_data[the_rest, :], axis =0)
            sub = memory_spot[curr_sub][-18:-12]
            
            recall_status = int(memory_spot[curr_sub][-5:-4])
            recognition_status = int(memory_spot2[curr_sub][-5:-4])
            
            
            isc = np.corrcoef(curr_sub_data, other_data)[0,1]
            
            #'''
            print(sub)
            print(current_condition)
            print(current_spot)
            print('recall_status: {}'.format(recall_status) )
            print('recognition_status: {}'.format(recognition_status) )
            print(isc)
            print('---')#'''


            df.loc[(df['subject'] == sub) & (df['condition'] == current_condition) & (df['spot'] == current_spot), 'isc_ind2rest'] = isc  
            df.loc[(df['subject'] == sub) & (df['condition'] == current_condition) & (df['spot'] == current_spot), 'recall']       = recall_status  
            df.loc[(df['subject'] == sub) & (df['condition'] == current_condition) & (df['spot'] == current_spot), 'recognition']  = recognition_status  
            #print( df.loc[(df['subject'] == sub) & (df['condition'] == current_condition) & (df['spot'] == current_spot)].values)
            

df = df.dropna(axis=0, how='any', subset=['isc_ind2rest'])

df.head()
# Out:
# commercial_aribnb_30s
# 100
# (20, 425)
# sub001
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 0
# 0.40475559496387953
# ---
# sub002
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.2705226531241173
# ---
# sub007
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.6727648672164781
# ---
# sub008
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.3471946593515282
# ---
# sub013
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7473686255357995
# ---
# sub014
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7516822339060725
# ---
# sub019
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.8948281483322207
# ---
# sub020
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 0
# 0.7600332476704318
# ---
# sub025
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.8234397850230152
# ---
# sub026
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.614684008161731
# ---
# sub031
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7589744373661049
# ---
# sub032
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.7119234268776525
# ---
# sub037
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.602370310625136
# ---
# sub038
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7884048548130865
# ---
# sub043
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.8497734437720527
# ---
# sub044
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 0
# 0.8506566354447539
# ---
# sub049
# 100
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.6522508452454779
# ---
# sub050
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7289281907588733
# ---
# sub055
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.6051359494816128
# ---
# sub056
# 100
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.8678506250306826
# ---
# 50nd
# (19, 425)
# sub005
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.015650662858275922
# ---
# sub006
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.016074700029606807
# ---
# sub011
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.6705775881065116
# ---
# sub012
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.4551646345260187
# ---
# sub017
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.5348618141519573
# ---
# sub018
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.5398910850005619
# ---
# sub023
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.6871803232258403
# ---
# sub024
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.41266039914035674
# ---
# sub029
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.32084155535915776
# ---
# sub030
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.468137683129132
# ---
# sub035
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 0
# 0.7164264878444254
# ---
# sub041
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.4402739321554936
# ---
# sub042
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.6969543644759546
# ---
# sub047
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.3974183367493066
# ---
# sub048
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.48525659300036456
# ---
# sub053
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.5365066381973292
# ---
# sub054
# 50nd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.8561067170105466
# ---
# sub059
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7877304810802055
# ---
# sub060
# 50nd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7254481633823455
# ---
# 50wd
# (20, 425)
# sub003
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.26120197797499484
# ---
# sub004
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.4048132600610989
# ---
# sub009
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# -0.29846000997439515
# ---
# sub010
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.26039286321492666
# ---
# sub015
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.2597603404680149
# ---
# sub016
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.6155838325012206
# ---
# sub021
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.04798979474478722
# ---
# sub022
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.7706595342694629
# ---
# sub027
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 0
# 0.1809819567782097
# ---
# sub028
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.24882573953044365
# ---
# sub033
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.5061528308272711
# ---
# sub034
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.1350656763211887
# ---
# sub039
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.22461310209643912
# ---
# sub040
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 0
# 0.028792850261310045
# ---
# sub045
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.45911159950421515
# ---
# sub046
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.42858010946215896
# ---
# sub051
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 1
# 0.468176329177224
# ---
# sub052
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.7654348902855704
# ---
# sub057
# 50wd
# commercial_aribnb_30s
# recall_status: 0
# recognition_status: 0
# 0.5548565547743728
# ---
# sub058
# 50wd
# commercial_aribnb_30s
# recall_status: 1
# recognition_status: 1
# 0.43869875638699596
# ---
# commercial_att_30s
# 100
# (19, 425)
# sub004
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.13362989254465532
# ---
# sub006
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.3993268247971331
# ---
# sub010
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.03412151561295792
# ---
# sub012
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.380456701280045
# ---
# sub016
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.5028079297444805
# ---
# sub018
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.5809888459997535
# ---
# sub022
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6336075579850334
# ---
# sub024
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.7508011712274679
# ---
# sub028
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.7807104388877322
# ---
# sub030
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6789265402323487
# ---
# sub034
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6041643968874642
# ---
# sub040
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.8181765346892269
# ---
# sub042
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.5864227153559911
# ---
# sub046
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6975655863921426
# ---
# sub048
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.7836197967973012
# ---
# sub052
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# -0.04520703752344688
# ---
# sub054
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.5928334457052347
# ---
# sub058
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6896234056080247
# ---
# sub060
# 100
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# -0.33998097684692435
# ---
# 50nd
# (20, 425)
# sub001
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.3400531898078295
# ---
# sub003
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.41078973257146495
# ---
# sub007
# 50nd
# commercial_att_30s
# recall_status: 1
# recognition_status: 1
# 0.3992732146315209
# ---
# sub009
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.30143437011322083
# ---
# sub013
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.5931924522425727
# ---
# sub015
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6450772564743285
# ---
# sub019
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.5501627619436913
# ---
# sub021
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.5045764232432498
# ---
# sub025
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.8486711508358094
# ---
# sub027
# 50nd
# commercial_att_30s
# recall_status: 1
# recognition_status: 1
# 0.6840063371735388
# ---
# sub031
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.8234391787892787
# ---
# sub033
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6671651380003212
# ---
# sub037
# 50nd
# commercial_att_30s
# recall_status: 1
# recognition_status: 1
# 0.11768216309160283
# ---
# sub039
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.8643746281642237
# ---
# sub043
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.8361336405057496
# ---
# sub045
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.6713360340840201
# ---
# sub049
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.8386422149915173
# ---
# sub051
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.1332817430626957
# ---
# sub055
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.393404512084548
# ---
# sub057
# 50nd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.23644403716994478
# ---
# 50wd
# (20, 425)
# sub002
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# -0.09175081662566248
# ---
# sub005
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# -0.3626656998500662
# ---
# sub008
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# -0.05216316814089695
# ---
# sub011
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.3992845198030519
# ---
# sub014
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# -0.04251418047217766
# ---
# sub017
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.035771735536471574
# ---
# sub020
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.3266136870998925
# ---
# sub023
# 50wd
# commercial_att_30s
# recall_status: 1
# recognition_status: 1
# 0.18080544491622857
# ---
# sub026
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.15795692442154435
# ---
# sub029
# 50wd
# commercial_att_30s
# recall_status: 1
# recognition_status: 1
# 0.0901151352380504
# ---
# sub032
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.4304104378669515
# ---
# sub035
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.42713648513310876
# ---
# sub038
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.3382162185975649
# ---
# sub041
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.3227947169671699
# ---
# sub044
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.07982167563841802
# ---
# sub047
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 0
# 0.08613333962775235
# ---
# sub050
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# -0.12322983356935782
# ---
# sub053
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.14706810642267903
# ---
# sub056
# 50wd
# commercial_att_30s
# recall_status: 0
# recognition_status: 1
# 0.457050911537815
# ---
# sub059
# 50wd
# commercial_att_30s
# recall_status: 1
# recognition_status: 0
# 0.1881903717443465
# ---
# commercial_carscom_30s
# 100
# (20, 425)
# sub001
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.5231078990802117
# ---
# sub002
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.2587312556655904
# ---
# sub007
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.45577657319808207
# ---
# sub008
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.38655420607286567
# ---
# sub013
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.7221864088672701
# ---
# sub014
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.48074154294734595
# ---
# sub019
# 100
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.7636540336551095
# ---
# sub020
# 100
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.5712445068409919
# ---
# sub025
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.6813143301126705
# ---
# sub026
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.7888949945125351
# ---
# sub031
# 100
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 0
# 0.5297806255853946
# ---
# sub032
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.7446534287919886
# ---
# sub037
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.7129549607308958
# ---
# sub038
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.6912815949564473
# ---
# sub043
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.78254658109107
# ---
# sub044
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5348213795579245
# ---
# sub049
# 100
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.8934313933207323
# ---
# sub050
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.39009083113887716
# ---
# sub055
# 100
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.6702875391212539
# ---
# sub056
# 100
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.7314018205722361
# ---
# 50nd
# (18, 425)
# sub005
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.2297309489748519
# ---
# sub006
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.21198043221166066
# ---
# sub011
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.6297295831611411
# ---
# sub017
# 50nd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.27273963823132497
# ---
# sub018
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.2335545504052663
# ---
# sub023
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.29444469344228474
# ---
# sub024
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.19264238367435588
# ---
# sub029
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5324702452838893
# ---
# sub030
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.536078383834163
# ---
# sub035
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5430659288078996
# ---
# sub041
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.7518836253147937
# ---
# sub042
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.696579855913914
# ---
# sub047
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5233496867849874
# ---
# sub048
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.7080008683243192
# ---
# sub053
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.5532142445445166
# ---
# sub054
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5323183234133405
# ---
# sub059
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.38565632710218667
# ---
# sub060
# 50nd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.4079921058222607
# ---
# 50wd
# (20, 425)
# sub003
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.24236806170592567
# ---
# sub004
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.43075710739633394
# ---
# sub009
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 0
# 0.18144269820304615
# ---
# sub010
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.06033080455491456
# ---
# sub015
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.6570709820431239
# ---
# sub016
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5250895942810526
# ---
# sub021
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5262374026370926
# ---
# sub022
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.7924110474948283
# ---
# sub027
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.7215319764974125
# ---
# sub028
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.6113978664412245
# ---
# sub033
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.18558624319553768
# ---
# sub034
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.743442001683489
# ---
# sub039
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.38117591559103564
# ---
# sub040
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.7211703635783603
# ---
# sub045
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 1
# 0.5629866355776814
# ---
# sub046
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 0
# 0.6706787868846114
# ---
# sub051
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.6664029539440449
# ---
# sub052
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# -0.3889092314888445
# ---
# sub057
# 50wd
# commercial_carscom_30s
# recall_status: 0
# recognition_status: 0
# 0.5641973564073929
# ---
# sub058
# 50wd
# commercial_carscom_30s
# recall_status: 1
# recognition_status: 1
# 0.3974854087733068
# ---
# commercial_cookies_30s
# 100
# (20, 425)
# sub001
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.21757352218259718
# ---
# sub002
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5565299665442623
# ---
# sub007
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.8001248372908009
# ---
# sub008
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5239515140069894
# ---
# sub013
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7616123958012149
# ---
# sub014
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5898807919582042
# ---
# sub019
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 0
# 0.7370543870389774
# ---
# sub020
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.8065647609378706
# ---
# sub025
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.779492982426019
# ---
# sub026
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.8878872172750538
# ---
# sub031
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7170994626729501
# ---
# sub032
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.702173027825812
# ---
# sub037
# 100
# commercial_cookies_30s
# recall_status: 1
# recognition_status: 1
# 0.8526934277298416
# ---
# sub038
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.6708710184056099
# ---
# sub043
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.6636541118969366
# ---
# sub044
# 100
# commercial_cookies_30s
# recall_status: 1
# recognition_status: 1
# 0.7742697127733436
# ---
# sub049
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7241270863041404
# ---
# sub050
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5125577721095842
# ---
# sub055
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.8305870019294169
# ---
# sub056
# 100
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7492787663406865
# ---
# 50nd
# (19, 425)
# sub005
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# -0.3856887523669882
# ---
# sub006
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# -0.2539923860246961
# ---
# sub011
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5896485050361467
# ---
# sub012
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7126311836286506
# ---
# sub017
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5625452875290626
# ---
# sub018
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.4511294185092635
# ---
# sub023
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5432985285873396
# ---
# sub024
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.1763181801917992
# ---
# sub029
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# -0.14896907286685826
# ---
# sub030
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5141665436658666
# ---
# sub035
# 50nd
# commercial_cookies_30s
# recall_status: 1
# recognition_status: 0
# 0.6660667998654336
# ---
# sub041
# 50nd
# commercial_cookies_30s
# recall_status: 1
# recognition_status: 1
# -0.021206029001291874
# ---
# sub042
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5626099708311302
# ---
# sub047
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.6186086466393226
# ---
# sub048
# 50nd
# commercial_cookies_30s
# recall_status: 1
# recognition_status: 1
# 0.47736037170644147
# ---
# sub053
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.47409742154795054
# ---
# sub054
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# -0.3672029505491387
# ---
# sub059
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.6839725284834293
# ---
# sub060
# 50nd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.025694261060153226
# ---
# 50wd
# (20, 425)
# sub003
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.1652551527506487
# ---
# sub004
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7111028580592761
# ---
# sub009
# 50wd
# commercial_cookies_30s
# recall_status: 1
# recognition_status: 1
# 0.23929596872662914
# ---
# sub010
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.06995908925570657
# ---
# sub015
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 0
# -0.27623820133200544
# ---
# sub016
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 0
# 0.516461836162627
# ---
# sub021
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7037969102362789
# ---
# sub022
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.8661822557144907
# ---
# sub027
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.3377792529746259
# ---
# sub028
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.6904594527650777
# ---
# sub033
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5323430558865142
# ---
# sub034
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.6743618661139525
# ---
# sub039
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7533436362240145
# ---
# sub040
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.5912046962124625
# ---
# sub045
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 0
# 0.40360667449423343
# ---
# sub046
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.48497390439434085
# ---
# sub051
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.7381440961468898
# ---
# sub052
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.49751325253542333
# ---
# sub057
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.005850506461119097
# ---
# sub058
# 50wd
# commercial_cookies_30s
# recall_status: 0
# recognition_status: 1
# 0.8636240068802953
# ---
# commercial_dominos_30s
# 100
# (20, 425)
# sub001
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.45555991177887567
# ---
# sub002
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.48190182345700533
# ---
# sub007
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.49934829212129134
# ---
# sub008
# 100
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.39796415558845366
# ---
# sub013
# 100
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.6762877588023132
# ---
# sub014
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6332811082160975
# ---
# sub019
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6800559921178364
# ---
# sub020
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.546053657062569
# ---
# sub025
# 100
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.6148244252012188
# ---
# sub026
# 100
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.7814778681306399
# ---
# sub031
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.903589469958036
# ---
# sub032
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6227953645492084
# ---
# sub037
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6965546926630524
# ---
# sub038
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6654537721254459
# ---
# sub043
# 100
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.7688667020039031
# ---
# sub044
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6173688451655092
# ---
# sub049
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.7048286641405722
# ---
# sub050
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.014937053984995122
# ---
# sub055
# 100
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.7355773915106267
# ---
# sub056
# 100
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.839071225616098
# ---
# 50nd
# (18, 425)
# sub005
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# -0.04537575603840363
# ---
# sub006
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# -0.5020477236831579
# ---
# sub011
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.5937852005668683
# ---
# sub017
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.16272538314624505
# ---
# sub018
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.43705625794541814
# ---
# sub023
# 50nd
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.028263498133164772
# ---
# sub024
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.4096754479863397
# ---
# sub029
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.09877318625834032
# ---
# sub030
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.5535702098590479
# ---
# sub035
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.5590305304575743
# ---
# sub041
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.7661801485657896
# ---
# sub042
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.36774234054653143
# ---
# sub047
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 0
# 0.6855403505648882
# ---
# sub048
# 50nd
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.6586254174380479
# ---
# sub053
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.5290887537827382
# ---
# sub054
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# -0.36252804486813756
# ---
# sub059
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6172666753205887
# ---
# sub060
# 50nd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# -0.38909960014698297
# ---
# 50wd
# (20, 425)
# sub003
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6152537720174018
# ---
# sub004
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 0
# -0.10007848126121398
# ---
# sub009
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.27931766966583876
# ---
# sub010
# 50wd
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.0461605392937153
# ---
# sub015
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.44840927933561325
# ---
# sub016
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 0
# 0.2800814278752419
# ---
# sub021
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.47831108572971365
# ---
# sub022
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.11576617624044078
# ---
# sub027
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.30563441117480944
# ---
# sub028
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.5271537697420275
# ---
# sub033
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 0
# 0.6579192942016296
# ---
# sub034
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.336986242774632
# ---
# sub039
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6333124486342949
# ---
# sub040
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.6145822935593175
# ---
# sub045
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.21921831279259787
# ---
# sub046
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 0
# 0.6942201622832559
# ---
# sub051
# 50wd
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.44558133612183876
# ---
# sub052
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.41875070109435814
# ---
# sub057
# 50wd
# commercial_dominos_30s
# recall_status: 0
# recognition_status: 1
# 0.768702091896987
# ---
# sub058
# 50wd
# commercial_dominos_30s
# recall_status: 1
# recognition_status: 1
# 0.6746978507102741
# ---
# commercial_doritos_30s
# 100
# (19, 425)
# sub001
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.627832140183798
# ---
# sub002
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.7572033657513403
# ---
# sub007
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.5942881876710698
# ---
# sub008
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.4993896176137228
# ---
# sub013
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.8164580866947564
# ---
# sub014
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# -0.0997201189867054
# ---
# sub019
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.9284310450653009
# ---
# sub020
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8397484515819501
# ---
# sub025
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.8531079859466146
# ---
# sub026
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8399664352470508
# ---
# sub031
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8587624452835753
# ---
# sub032
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.818212293093614
# ---
# sub037
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.9320339441809695
# ---
# sub038
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8616933814160147
# ---
# sub043
# 100
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.8843452607503139
# ---
# sub044
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.5994292717128721
# ---
# sub049
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8285126572507776
# ---
# sub050
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.2785363548439441
# ---
# sub056
# 100
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.6423156610069322
# ---
# 50nd
# (18, 425)
# sub005
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.30368481082612364
# ---
# sub006
# 50nd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.5831217187330077
# ---
# sub011
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8094979468200072
# ---
# sub017
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.867786142696646
# ---
# sub018
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.7282000174168349
# ---
# sub023
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.7449092936885016
# ---
# sub024
# 50nd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.8478680775328855
# ---
# sub029
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.6118890607982668
# ---
# sub030
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.9241240564979579
# ---
# sub035
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.786592325960178
# ---
# sub041
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.959610582757891
# ---
# sub042
# 50nd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.8814062513456209
# ---
# sub047
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.7537814248771061
# ---
# sub048
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8088760471825786
# ---
# sub053
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.7368211558556947
# ---
# sub054
# 50nd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8149810218738677
# ---
# sub059
# 50nd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.8052687982720551
# ---
# sub060
# 50nd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.9119628957662399
# ---
# 50wd
# (20, 425)
# sub003
# 50wd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.658058852604147
# ---
# sub004
# 50wd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.6685394331357197
# ---
# sub009
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.4409914674596915
# ---
# sub010
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.2687453603891494
# ---
# sub015
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.4356576290845538
# ---
# sub016
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.5136498102089436
# ---
# sub021
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8217846711881561
# ---
# sub022
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.6703476211723154
# ---
# sub027
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.5013190113619777
# ---
# sub028
# 50wd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.8663437588629728
# ---
# sub033
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8449523576427319
# ---
# sub034
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.7332598676034636
# ---
# sub039
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8249193418878804
# ---
# sub040
# 50wd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.7065650555634293
# ---
# sub045
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.7350918062349123
# ---
# sub046
# 50wd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 0
# 0.9380327972956274
# ---
# sub051
# 50wd
# commercial_doritos_30s
# recall_status: 1
# recognition_status: 1
# 0.2682383155683099
# ---
# sub052
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.6389736172983673
# ---
# sub057
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.5994884814064809
# ---
# sub058
# 50wd
# commercial_doritos_30s
# recall_status: 0
# recognition_status: 1
# 0.8266958933716928
# ---
# commercial_expedia_30s
# 100
# (20, 425)
# sub001
# 100
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 1
# 0.302099486289897
# ---
# sub002
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.5508022976780609
# ---
# sub007
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.5978256812537956
# ---
# sub008
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.7159078422231235
# ---
# sub013
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.8726846773846059
# ---
# sub014
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.5109734844186918
# ---
# sub019
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.5480426199475423
# ---
# sub020
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.4376346445329973
# ---
# sub025
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.7081033746651959
# ---
# sub026
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.22293264861470116
# ---
# sub031
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.42482813365787
# ---
# sub032
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.785750494216392
# ---
# sub037
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.7591628815949134
# ---
# sub038
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.7435017984041183
# ---
# sub043
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.8176190347442022
# ---
# sub044
# 100
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 1
# 0.5129681013700605
# ---
# sub049
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.8657793929233265
# ---
# sub050
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.2541928073315321
# ---
# sub055
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.8628199458100788
# ---
# sub056
# 100
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.4652083928463012
# ---
# 50nd
# (19, 425)
# sub005
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.34284855448283863
# ---
# sub006
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.6444744866555776
# ---
# sub011
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.8716439090743568
# ---
# sub012
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.6376079511412039
# ---
# sub017
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.24022580451927944
# ---
# sub018
# 50nd
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 1
# 0.27140361999136386
# ---
# sub023
# 50nd
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 1
# 0.5179153788403394
# ---
# sub024
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.4566776619102939
# ---
# sub029
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.31452201378706146
# ---
# sub030
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.5262359139836551
# ---
# sub035
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.47432649306726843
# ---
# sub041
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.7865848893058075
# ---
# sub042
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.5120347309315499
# ---
# sub047
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.8459982606165698
# ---
# sub048
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.6883744368636762
# ---
# sub053
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# -0.05780253482247295
# ---
# sub054
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.4992278279674871
# ---
# sub059
# 50nd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.42784367289049063
# ---
# sub060
# 50nd
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 1
# -0.5045939633640634
# ---
# 50wd
# (20, 425)
# sub003
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.2626954992901903
# ---
# sub004
# 50wd
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 1
# 0.3767985854315885
# ---
# sub009
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.32424965380307996
# ---
# sub010
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.5349341377818579
# ---
# sub015
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.2353225632819158
# ---
# sub016
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.37087292935141686
# ---
# sub021
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.4807953646573166
# ---
# sub022
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.436922712812259
# ---
# sub027
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.21716591677123476
# ---
# sub028
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.6155015740951281
# ---
# sub033
# 50wd
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 0
# 0.5505906942454183
# ---
# sub034
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.4344827323224816
# ---
# sub039
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.02448061582284782
# ---
# sub040
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.4268507863122411
# ---
# sub045
# 50wd
# commercial_expedia_30s
# recall_status: 1
# recognition_status: 0
# 0.5326994781368842
# ---
# sub046
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.4959040895614488
# ---
# sub051
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# 0.5066204115115756
# ---
# sub052
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# -0.00042199269930951567
# ---
# sub057
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 0
# 0.5477922257740924
# ---
# sub058
# 50wd
# commercial_expedia_30s
# recall_status: 0
# recognition_status: 1
# -0.21639049077153524
# ---
# commercial_google_pixel_30s
# 100
# (20, 425)
# sub003
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.7727162338799575
# ---
# sub005
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.3034560479606894
# ---
# sub009
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6965095731578098
# ---
# sub011
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6688250482509437
# ---
# sub015
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6646600297841602
# ---
# sub017
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6052065283648753
# ---
# sub021
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8461276811305187
# ---
# sub023
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8354891708887133
# ---
# sub027
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6437073690037611
# ---
# sub029
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8103594998372594
# ---
# sub033
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.9016166901655026
# ---
# sub035
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.8063531750994317
# ---
# sub039
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8902454516265876
# ---
# sub041
# 100
# commercial_google_pixel_30s
# recall_status: 1
# recognition_status: 1
# 0.9293680035011468
# ---
# sub045
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.8444017310657169
# ---
# sub047
# 100
# commercial_google_pixel_30s
# recall_status: 1
# recognition_status: 1
# 0.8442422717085456
# ---
# sub051
# 100
# commercial_google_pixel_30s
# recall_status: 1
# recognition_status: 1
# 0.8902631344624273
# ---
# sub053
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.5646648869490054
# ---
# sub057
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.9345409810556674
# ---
# sub059
# 100
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.9158859589188677
# ---
# 50nd
# (20, 425)
# sub002
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8426085697947288
# ---
# sub004
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.7693706976829823
# ---
# sub008
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.7416947427382289
# ---
# sub010
# 50nd
# commercial_google_pixel_30s
# recall_status: 1
# recognition_status: 1
# 0.5190005021206885
# ---
# sub014
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6148281411562291
# ---
# sub016
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.7561300341356026
# ---
# sub020
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.822945610208825
# ---
# sub022
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6907433627337474
# ---
# sub026
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.1304928112151872
# ---
# sub028
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.8487353905685066
# ---
# sub032
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.5520105177396409
# ---
# sub034
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.7861850831822031
# ---
# sub038
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.5959342466908971
# ---
# sub040
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8715768191004672
# ---
# sub044
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# -0.35354229487742084
# ---
# sub046
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.7421083246133429
# ---
# sub050
# 50nd
# commercial_google_pixel_30s
# recall_status: 1
# recognition_status: 1
# -0.3929674133345446
# ---
# sub052
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8144858455409942
# ---
# sub056
# 50nd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.5873428022908197
# ---
# sub058
# 50nd
# commercial_google_pixel_30s
# recall_status: 1
# recognition_status: 1
# 0.6429925027914801
# ---
# 50wd
# (19, 425)
# sub001
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.7168038235980609
# ---
# sub006
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.4165792331519503
# ---
# sub007
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.4220776845914263
# ---
# sub012
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.875239525623638
# ---
# sub013
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6975265618964543
# ---
# sub018
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6640336433975624
# ---
# sub019
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.36624303358255544
# ---
# sub024
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.5766279972480182
# ---
# sub025
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.3440007622208681
# ---
# sub030
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.39170998174267696
# ---
# sub031
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# -0.09943590599547554
# ---
# sub037
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.0364827669600638
# ---
# sub042
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.8036381306168051
# ---
# sub043
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.8045588818021242
# ---
# sub048
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.7842421643725357
# ---
# sub049
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 0
# 0.40833256026562736
# ---
# sub054
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.19649929041713318
# ---
# sub055
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.6398748048475211
# ---
# sub060
# 50wd
# commercial_google_pixel_30s
# recall_status: 0
# recognition_status: 1
# 0.24872258032594752
# ---
# commercial_hr_block_30s
# 100
# (20, 425)
# sub003
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.8867464022763951
# ---
# sub005
# 100
# commercial_hr_block_30s
# recall_status: 1
# recognition_status: 1
# 0.6405997901724554
# ---
# sub009
# 100
# commercial_hr_block_30s
# recall_status: 1
# recognition_status: 1
# 0.6902976630978874
# ---
# sub011
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.865425246250947
# ---
# sub015
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.8111065071621495
# ---
# sub017
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.3828685097745622
# ---
# sub021
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.6301646273099967
# ---
# sub023
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.6618623356806512
# ---
# sub027
# 100
# commercial_hr_block_30s
# recall_status: 1
# recognition_status: 1
# 0.862376617370815
# ---
# sub029
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# -0.06971952559979816
# ---
# sub033
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.8240872119751348
# ---
# sub035
# 100
# commercial_hr_block_30s
# recall_status: 1
# recognition_status: 1
# 0.7290746913954607
# ---
# sub039
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.9272885168920805
# ---
# sub041
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.8691706025967211
# ---
# sub045
# 100
# commercial_hr_block_30s
# recall_status: 1
# recognition_status: 1
# 0.8061136186805147
# ---
# sub047
# 100
# commercial_hr_block_30s
# recall_status: 1
# recognition_status: 1
# 0.7025192768345617
# ---
# sub051
# 100
# commercial_hr_block_30s
# recall_status: 1
# recognition_status: 1
# 0.8428424715131662
# ---
# sub053
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.8380920796197524
# ---
# sub057
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.04447364658921167
# ---
# sub059
# 100
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.5437915577795259
# ---
# 50nd
# (20, 425)
# sub002
# 50nd
# commercial_hr_block_30s
# recall_status: 0
# recognition_status: 1
# 0.6925382879906257
# ---
# sub004
# 50nd
# ...
# 0.7804091185925833
# ---
# sub030
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.7550626976944231
# ---
# sub034
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.8809504952006161
# ---
# sub040
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.0600991589413595
# ---
# sub042
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.5419332925364285
# ---
# sub046
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.3562147364953987
# ---
# sub048
# 100
# health_stroke_30s
# recall_status: 1
# recognition_status: 1
# 0.2529664633385033
# ---
# sub052
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.0338413630582686
# ---
# sub054
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.1684147790022224
# ---
# sub058
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.7141151085207933
# ---
# sub060
# 100
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# -0.15003343875608113
# ---
# 50nd
# (20, 425)
# sub001
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.5293750790968941
# ---
# sub003
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.6964090847248993
# ---
# sub007
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.5689695941237342
# ---
# sub009
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.696080185242016
# ---
# sub013
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.6547723235876728
# ---
# sub015
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.5310572525591877
# ---
# sub019
# 50nd
# health_stroke_30s
# recall_status: 1
# recognition_status: 1
# 0.7292364897080343
# ---
# sub021
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.5819024879644142
# ---
# sub025
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.5452782034368995
# ---
# sub027
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.6098837942543219
# ---
# sub031
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.7651952212489848
# ---
# sub033
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.9262224305566072
# ---
# sub037
# 50nd
# health_stroke_30s
# recall_status: 1
# recognition_status: 1
# 0.44334222941314344
# ---
# sub039
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.16088682472096674
# ---
# sub043
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.46988645061357376
# ---
# sub045
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.6716205899339083
# ---
# sub049
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.20232911109410037
# ---
# sub051
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.6021856459752482
# ---
# sub055
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.7144918489948906
# ---
# sub057
# 50nd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.3597224457495347
# ---
# 50wd
# (20, 425)
# sub002
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.1142246658350735
# ---
# sub005
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.0468217521266025
# ---
# sub008
# 50wd
# health_stroke_30s
# recall_status: 1
# recognition_status: 1
# 0.6843447317849009
# ---
# sub011
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.49424959256091916
# ---
# sub014
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.5373167991634489
# ---
# sub017
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.013212777993285466
# ---
# sub020
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.5408450985846783
# ---
# sub023
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.6414556642656529
# ---
# sub026
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.3967935899633436
# ---
# sub029
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.32348523521635253
# ---
# sub032
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.40470699831851403
# ---
# sub035
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.3967017322619099
# ---
# sub038
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.6483779218241259
# ---
# sub041
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.4046293948348928
# ---
# sub044
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# 0.6777732546256189
# ---
# sub047
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# -0.010765990920645112
# ---
# sub050
# 50wd
# health_stroke_30s
# recall_status: 1
# recognition_status: 1
# 0.35441719276716926
# ---
# sub053
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 0
# -0.21953445667119045
# ---
# sub056
# 50wd
# health_stroke_30s
# recall_status: 0
# recognition_status: 1
# 0.2505837015923043
# ---
# sub059
# 50wd
# health_stroke_30s
# recall_status: 1
# recognition_status: 1
# 0.4409076634570013
# ---
# health_vaping_30s
# 100
# (18, 425)
# sub004
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.5176814130529978
# ---
# sub006
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 0
# -0.02752064583999582
# ---
# sub010
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.3267001095819289
# ---
# sub016
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.6618611437167582
# ---
# sub018
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.4226147787440797
# ---
# sub022
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8918512127823189
# ---
# sub024
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8317835023566004
# ---
# sub028
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8086429667133438
# ---
# sub030
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8484748050857234
# ---
# sub034
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.826928381994659
# ---
# sub040
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.5903013137881032
# ---
# sub042
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.6746656462354481
# ---
# sub046
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.6676277679422351
# ---
# sub048
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.6823411037827269
# ---
# sub052
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# -0.08486393658807795
# ---
# sub054
# 100
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.8579347710206826
# ---
# sub058
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.7478234624594184
# ---
# sub060
# 100
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8782147629092402
# ---
# 50nd
# (20, 425)
# sub001
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 0
# 0.5820738789022498
# ---
# sub003
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.024732555881166948
# ---
# sub007
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.7537029682663123
# ---
# sub009
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.5539330769951466
# ---
# sub013
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.8998561660980965
# ---
# sub015
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# -0.08638824256230283
# ---
# sub019
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.8133747861114642
# ---
# sub021
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.1496364501220761
# ---
# sub025
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 0
# 0.34940264823259226
# ---
# sub027
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8781212243465393
# ---
# sub031
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.6216745965481815
# ---
# sub033
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.9302722399097088
# ---
# sub037
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.7734870108412868
# ---
# sub039
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.6742372706849209
# ---
# sub043
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.6933080525886323
# ---
# sub045
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8941048974103935
# ---
# sub049
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.9073374426450009
# ---
# sub051
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.7826505596813071
# ---
# sub055
# 50nd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.8131040321823597
# ---
# sub057
# 50nd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.8112340344741554
# ---
# 50wd
# (20, 425)
# sub002
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 0
# 0.48069916101357324
# ---
# sub005
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# -0.2021815131202529
# ---
# sub008
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# -0.2618124057150594
# ---
# sub011
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.4413749096161697
# ---
# sub014
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.1660986076010594
# ---
# sub017
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.10819649303052604
# ---
# sub020
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 0
# 0.6996434448797927
# ---
# sub023
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 0
# 0.14898986221295632
# ---
# sub026
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 0
# 0.33062458882254325
# ---
# sub029
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.2054740070383057
# ---
# sub032
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.25227312788505524
# ---
# sub035
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.33066806597191084
# ---
# sub038
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.7504032504491474
# ---
# sub041
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.5342897458762597
# ---
# sub044
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.5913559395712579
# ---
# sub047
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# -0.08449770578343116
# ---
# sub050
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.17042668573437547
# ---
# sub053
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 0
# 0.5957173523695494
# ---
# sub056
# 50wd
# health_vaping_30s
# recall_status: 0
# recognition_status: 1
# 0.7128719088975419
# ---
# sub059
# 50wd
# health_vaping_30s
# recall_status: 1
# recognition_status: 1
# 0.7097607342161278
# ---
# health_weight_30s
# 100
# (19, 425)
# sub004
# 100
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.5655252337002545
# ---
# sub006
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.5164890978345565
# ---
# sub010
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.06588094753468877
# ---
# sub012
# 100
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.7748364681569845
# ---
# sub016
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# -0.0722686247997245
# ---
# sub018
# 100
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.6118198100532437
# ---
# sub022
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.6817776795094245
# ---
# sub024
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.5999699310058667
# ---
# sub028
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.7508140210687396
# ---
# sub030
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.5706545694539059
# ---
# sub034
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.7576642235034141
# ---
# sub040
# 100
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.49112445727228826
# ---
# sub042
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.3019595384189959
# ---
# sub046
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.7355506271744016
# ---
# sub048
# 100
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.18621041668008143
# ---
# sub052
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.06007499141647971
# ---
# sub054
# 100
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.7898123617729644
# ---
# sub058
# 100
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.6848764795610044
# ---
# sub060
# 100
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.44821773077916266
# ---
# 50nd
# (19, 425)
# sub001
# 50nd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.03575605530104858
# ---
# sub003
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.13763653439696513
# ---
# sub007
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.6549942458831567
# ---
# sub009
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.20806859543430153
# ---
# sub013
# 50nd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.8296215800644634
# ---
# sub015
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.10220524794857641
# ---
# sub019
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.6675798243534063
# ---
# sub021
# 50nd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.6182360400797775
# ---
# sub025
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.7497984887642488
# ---
# sub027
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.6790560118584519
# ---
# sub031
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.6610116420175122
# ---
# sub033
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.4871816570985799
# ---
# sub037
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.3046303652173233
# ---
# sub039
# 50nd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.7796948114321998
# ---
# sub043
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.6382257126982476
# ---
# sub045
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.810963982934952
# ---
# sub049
# 50nd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.6342664527854764
# ---
# sub051
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.8962705299989217
# ---
# sub057
# 50nd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.28441617304172995
# ---
# 50wd
# (20, 425)
# sub002
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.08270374635210015
# ---
# sub005
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.1312204552895661
# ---
# sub008
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.4691824767042508
# ---
# sub011
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.5228321731864247
# ---
# sub014
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.34777571197712825
# ---
# sub017
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.47769772530730314
# ---
# sub020
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.09353556370782236
# ---
# sub023
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.699914442981873
# ---
# sub026
# 50wd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.15122046049924073
# ---
# sub029
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.08852616867034119
# ---
# sub032
# 50wd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.7330209540917876
# ---
# sub035
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.5643783431125867
# ---
# sub038
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.5673237618560831
# ---
# sub041
# 50wd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.6118007538322098
# ---
# sub044
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.6774430636746437
# ---
# sub047
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 1
# 0.04712663118094875
# ---
# sub050
# 50wd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.06597486346525283
# ---
# sub053
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.5308593778275863
# ---
# sub056
# 50wd
# health_weight_30s
# recall_status: 1
# recognition_status: 1
# 0.14496312686134186
# ---
# sub059
# 50wd
# health_weight_30s
# recall_status: 0
# recognition_status: 0
# 0.6113899946543729
# ---
#    subject condition                    spot  recall  recognition  \
# 0   sub001       100   commercial_aribnb_30s     0.0          0.0
# 4   sub001      50nd      commercial_att_30s     0.0          1.0
# 6   sub001       100  commercial_carscom_30s     0.0          0.0
# 9   sub001       100  commercial_cookies_30s     0.0          1.0
# 12  sub001       100  commercial_dominos_30s     0.0          1.0
#
#     isc_ind2rest
# 0       0.404756
# 4       0.340053
# 6       0.523108
# 9       0.217574
# 12      0.455560

# %%
df.to_csv('../data/03_spots_memory_data/all_subs_spots_conditions_memory_isc_reproduce.csv', index=False)

# %%
df.head()
# Out:
#    subject condition                    spot  recall  recognition  \
# 0   sub001       100   commercial_aribnb_30s     0.0          0.0
# 4   sub001      50nd      commercial_att_30s     0.0          1.0
# 6   sub001       100  commercial_carscom_30s     0.0          0.0
# 9   sub001       100  commercial_cookies_30s     0.0          1.0
# 12  sub001       100  commercial_dominos_30s     0.0          1.0
#
#     isc_ind2rest
# 0       0.404756
# 4       0.340053
# 6       0.523108
# 9       0.217574
# 12      0.455560

# %%
aggregated_df = df.groupby(['condition', 'spot'])[['recall','recognition', 'isc_ind2rest']].mean().reset_index()
aggregated_df.head()
# Out:
#   condition                    spot  recall  recognition  isc_ind2rest
# 0       100   commercial_aribnb_30s    0.55         0.85      0.685177
# 1       100      commercial_att_30s    0.00         1.00      0.487505
# 2       100  commercial_carscom_30s    0.25         0.80      0.615673
# 3       100  commercial_cookies_30s    0.10         0.95      0.692899
# 4       100  commercial_dominos_30s    0.30         1.00      0.616790

# %%
aggregated_df.to_csv('../data/03_spots_memory_data/aggregated_df_reproduce.csv', index=False)
